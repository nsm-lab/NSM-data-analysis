# %%
from bat import bro_log_reader

# %%
reader = bro_log_reader.BroLogReader('../logs/zeek/dns.log')

# %%
for row in reader.readrows():
    print(row)
# Out:
# Successfully monitoring ../logs/zeek/dns.log...
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 39, 598395), 'uid': 'CuhC8j1wtiDYjCN', 'id.orig_h': '10.1.10.73', 'id.orig_p': 137, 'id.resp_h': '10.1.10.162', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 59451, 'rtt': datetime.timedelta(0), 'query': '-', 'qclass': 0, 'qclass_name': '-', 'qtype': 0, 'qtype_name': '-', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': False, 'RA': False, 'Z': 0, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863250), 'uid': 'CZjeEe3gQNWZXA8W7h', 'id.orig_h': '192.168.1.102', 'id.orig_p': 1170, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 975, 'rtt': datetime.timedelta(0), 'query': 'sn21.mailshell.net', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '87.106.13.62,212.227.96.110,212.227.97.133,87.106.1.47,87.106.1.89,87.106.9.29,87.106.12.77,87.106.13.61', 'TTLs': '10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863253), 'uid': 'CqiPZz1WMQDF3LYUyc', 'id.orig_h': '192.168.1.104', 'id.orig_p': 1174, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 8509, 'rtt': datetime.timedelta(0), 'query': 'sn21.mailshell.net', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '87.106.1.47,87.106.9.29,87.106.12.47,87.106.13.61,87.106.13.62,87.106.66.233,212.227.96.110,212.227.97.133', 'TTLs': '10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863255), 'uid': 'Cmxdfk12NB5YP72alk', 'id.orig_h': '192.168.1.1', 'id.orig_p': 5353, 'id.resp_h': '224.0.0.251', 'id.resp_p': 5353, 'proto': 'udp', 'trans_id': 0, 'rtt': datetime.timedelta(microseconds=1), 'query': '_rfb._tcp.local', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 12, 'qtype_name': 'PTR', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': True, 'TC': False, 'RD': False, 'RA': False, 'Z': 0, 'answers': 'TXT 15 model=Xserve1\\x2c1,domex.nps.edu._rfb._tcp.local', 'TTLs': '4500.000000,4500.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863256), 'uid': 'CcqB9mjglLGELhiQ6', 'id.orig_h': 'fe80::219:e3ff:fee7:5d23', 'id.orig_p': 5353, 'id.resp_h': 'ff02::fb', 'id.resp_p': 5353, 'proto': 'udp', 'trans_id': 0, 'rtt': datetime.timedelta(0), 'query': '_rfb._tcp.local', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 12, 'qtype_name': 'PTR', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': True, 'TC': False, 'RD': False, 'RA': False, 'Z': 0, 'answers': 'TXT 15 model=Xserve1\\x2c1,domex.nps.edu._rfb._tcp.local', 'TTLs': '4500.000000,4500.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863825), 'uid': 'Cwlbne4tP40aGUJi8d', 'id.orig_h': '192.168.1.102', 'id.orig_p': 1173, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 40612, 'rtt': datetime.timedelta(0), 'query': 'version.avg.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 16, 'qtype_name': 'TXT', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'TXT 120 AVG=9 TIME=00911172053 IAVI=2510 WIN=707 FIN=707 XPLSC=148 XPLSB2=117 XPLSB=99 XPLCF=6 XPLPH=12 SALS=362  CRC32=52c5cd49,TXT 120 AVG=8 TIME=00911172053 IAVI=2510 WIN=425 FIN=425 XPLSC=148 XPLSB2=117 XPLSB=99 XPLCF=6 XPLPH=12 SALS=362  CRC32=e27a00cb', 'TTLs': '4584.000000,4584.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863827), 'uid': 'Cmxdfk12NB5YP72alk', 'id.orig_h': '192.168.1.1', 'id.orig_p': 5353, 'id.resp_h': '224.0.0.251', 'id.resp_p': 5353, 'proto': 'udp', 'trans_id': 0, 'rtt': datetime.timedelta(microseconds=1), 'query': '_smb._tcp.local', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 12, 'qtype_name': 'PTR', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': True, 'TC': False, 'RD': False, 'RA': False, 'Z': 0, 'answers': 'TXT 15 model=Xserve1\\x2c1,domex.nps.edu._smb._tcp.local', 'TTLs': '4500.000000,4500.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863828), 'uid': 'CcqB9mjglLGELhiQ6', 'id.orig_h': 'fe80::219:e3ff:fee7:5d23', 'id.orig_p': 5353, 'id.resp_h': 'ff02::fb', 'id.resp_p': 5353, 'proto': 'udp', 'trans_id': 0, 'rtt': datetime.timedelta(0), 'query': '_smb._tcp.local', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 12, 'qtype_name': 'PTR', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': True, 'TC': False, 'RD': False, 'RA': False, 'Z': 0, 'answers': 'TXT 15 model=Xserve1\\x2c1,domex.nps.edu._smb._tcp.local', 'TTLs': '4500.000000,4500.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863834), 'uid': 'Cmxdfk12NB5YP72alk', 'id.orig_h': '192.168.1.1', 'id.orig_p': 5353, 'id.resp_h': '224.0.0.251', 'id.resp_p': 5353, 'proto': 'udp', 'trans_id': 0, 'rtt': datetime.timedelta(microseconds=524), 'query': '_adisk._tcp.local', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 12, 'qtype_name': 'PTR', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': True, 'TC': False, 'RD': False, 'RA': False, 'Z': 0, 'answers': 'TXT 15 model=Xserve1\\x2c1', 'TTLs': '4500.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863835), 'uid': 'CcqB9mjglLGELhiQ6', 'id.orig_h': 'fe80::219:e3ff:fee7:5d23', 'id.orig_p': 5353, 'id.resp_h': 'ff02::fb', 'id.resp_p': 5353, 'proto': 'udp', 'trans_id': 0, 'rtt': datetime.timedelta(microseconds=523), 'query': '_adisk._tcp.local', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 12, 'qtype_name': 'PTR', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': True, 'TC': False, 'RD': False, 'RA': False, 'Z': 0, 'answers': 'TXT 15 model=Xserve1\\x2c1', 'TTLs': '4500.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864376), 'uid': 'CJvFGNgzwMRIOxLyl', 'id.orig_h': '192.168.1.102', 'id.orig_p': 59040, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 55101, 'rtt': datetime.timedelta(microseconds=1), 'query': 'nist1.columbiacountyga.gov', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '68.216.79.113', 'TTLs': '10800.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864559), 'uid': 'CEiutg3qOIUWgH9vIi', 'id.orig_h': '192.168.1.103', 'id.orig_p': 1190, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 59648, 'rtt': datetime.timedelta(microseconds=1), 'query': 'sn21.mailshell.net', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '87.106.13.62,87.106.66.233,212.227.96.110,212.227.97.133,87.106.9.29,87.106.12.47,87.106.12.77,87.106.13.61', 'TTLs': '10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864573), 'uid': 'C4mkav3JPXUV9zgwU8', 'id.orig_h': '192.168.1.103', 'id.orig_p': 56940, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 10322, 'rtt': datetime.timedelta(0), 'query': 'nist1.columbiacountyga.gov', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '68.216.79.113', 'TTLs': '10096.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864577), 'uid': 'Ct5cOg3fXYasFSZCtf', 'id.orig_h': '192.168.1.104', 'id.orig_p': 56041, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 20713, 'rtt': datetime.timedelta(microseconds=1), 'query': 'nist1.columbiacountyga.gov', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '68.216.79.113', 'TTLs': '9982.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864772), 'uid': 'CSjpxgLsWGiHHrNak', 'id.orig_h': '192.168.1.104', 'id.orig_p': 56749, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 45193, 'rtt': datetime.timedelta(0), 'query': 'wpad.m57.biz', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 3, 'rcode_name': 'NXDOMAIN', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 0, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864773), 'uid': 'CYBjea1rTd9ENaCoQe', 'id.orig_h': '192.168.1.104', 'id.orig_p': 52125, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 12540, 'rtt': datetime.timedelta(0), 'query': 'download.windowsupdate.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'download.windowsupdate.nsatc.net,mscom-wui-sea.vo.msecnd.net,65.54.95.64,65.54.95.57', 'TTLs': '3600.000000,600.000000,300.000000,300.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864776), 'uid': 'C2RiH51bBaKbfO7yPh', 'id.orig_h': '192.168.1.104', 'id.orig_p': 64790, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 25603, 'rtt': datetime.timedelta(microseconds=1), 'query': 'www.update.microsoft.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'www.update.microsoft.com.nsatc.net,65.55.184.16', 'TTLs': '3600.000000,300.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864996), 'uid': 'CfQ3f42LtmgkkTEVw', 'id.orig_h': '192.168.1.102', 'id.orig_p': 1187, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 51811, 'rtt': datetime.timedelta(0), 'query': 'sn21.mailshell.net', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '212.227.97.133,87.106.1.47,87.106.1.89,87.106.9.29,87.106.12.47,87.106.12.77,87.106.13.61,87.106.66.233', 'TTLs': '10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865184), 'uid': 'CGKhoe1hkumDWj79j2', 'id.orig_h': '192.168.1.102', 'id.orig_p': 1196, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 958, 'rtt': datetime.timedelta(0), 'query': 'sn21.mailshell.net', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '87.106.12.47,87.106.12.77,87.106.13.61,87.106.13.62,87.106.66.233,212.227.97.133,87.106.1.47,87.106.1.89', 'TTLs': '10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865186), 'uid': 'Cv0gzA3IlKC5xWZPN2', 'id.orig_h': '192.168.1.103', 'id.orig_p': 1196, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 15722, 'rtt': datetime.timedelta(microseconds=1), 'query': 'version.avg.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 16, 'qtype_name': 'TXT', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'TXT 120 AVG=8 TIME=00911172053 IAVI=2510 WIN=425 FIN=425 XPLSC=148 XPLSB2=117 XPLSB=99 XPLCF=6 XPLPH=12 SALS=362  CRC32=e27a00cb,TXT 120 AVG=9 TIME=00911172053 IAVI=2510 WIN=707 FIN=707 XPLSC=148 XPLSB2=117 XPLSB=99 XPLCF=6 XPLPH=12 SALS=362  CRC32=52c5cd49', 'TTLs': '1291.000000,1291.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865187), 'uid': 'C1XerbGauKNwHpumj', 'id.orig_h': '192.168.1.103', 'id.orig_p': 57387, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 6683, 'rtt': datetime.timedelta(0), 'query': 'update.avg.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '212.96.161.238', 'TTLs': '600.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865194), 'uid': 'Cg1oEp2yy5joaJnVT2', 'id.orig_h': '192.168.1.104', 'id.orig_p': 1198, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 5811, 'rtt': datetime.timedelta(0), 'query': 'sn21.mailshell.net', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '87.106.13.62,87.106.66.233,212.227.96.110,212.227.97.133,87.106.1.47,87.106.12.47,87.106.12.77,87.106.13.61', 'TTLs': '10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865195), 'uid': 'CMX92T29DQzjemDack', 'id.orig_h': '192.168.1.104', 'id.orig_p': 1199, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 19188, 'rtt': datetime.timedelta(0), 'query': 'sn21.mailshell.net', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '212.227.97.133,87.106.1.47,87.106.1.89,87.106.9.29,87.106.13.61,87.106.13.62,87.106.66.233,212.227.96.110', 'TTLs': '10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865362), 'uid': 'Cmxdfk12NB5YP72alk', 'id.orig_h': '192.168.1.1', 'id.orig_p': 5353, 'id.resp_h': '224.0.0.251', 'id.resp_p': 5353, 'proto': 'udp', 'trans_id': 0, 'rtt': datetime.timedelta(0), 'query': '_rfb._tcp.local', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 12, 'qtype_name': 'PTR', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': True, 'TC': False, 'RD': False, 'RA': False, 'Z': 0, 'answers': 'TXT 15 model=Xserve1\\x2c1,domex.nps.edu._rfb._tcp.local', 'TTLs': '4500.000000,4500.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865362), 'uid': 'CcqB9mjglLGELhiQ6', 'id.orig_h': 'fe80::219:e3ff:fee7:5d23', 'id.orig_p': 5353, 'id.resp_h': 'ff02::fb', 'id.resp_p': 5353, 'proto': 'udp', 'trans_id': 0, 'rtt': datetime.timedelta(microseconds=1), 'query': '_rfb._tcp.local', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 12, 'qtype_name': 'PTR', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': True, 'TC': False, 'RD': False, 'RA': False, 'Z': 0, 'answers': 'TXT 15 model=Xserve1\\x2c1,domex.nps.edu._rfb._tcp.local', 'TTLs': '4500.000000,4500.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865373), 'uid': 'CtxfF727bu4Z51toI7', 'id.orig_h': '192.168.1.104', 'id.orig_p': 1208, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 20427, 'rtt': datetime.timedelta(microseconds=1), 'query': 'sn21.mailshell.net', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '87.106.12.47,87.106.12.77,87.106.13.61,87.106.13.62,87.106.66.233,212.227.97.133,87.106.1.47,87.106.1.89', 'TTLs': '10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865384), 'uid': 'Cmxdfk12NB5YP72alk', 'id.orig_h': '192.168.1.1', 'id.orig_p': 5353, 'id.resp_h': '224.0.0.251', 'id.resp_p': 5353, 'proto': 'udp', 'trans_id': 0, 'rtt': datetime.timedelta(0), 'query': '_smb._tcp.local', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 12, 'qtype_name': 'PTR', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': True, 'TC': False, 'RD': False, 'RA': False, 'Z': 0, 'answers': 'TXT 15 model=Xserve1\\x2c1,domex.nps.edu._smb._tcp.local', 'TTLs': '4500.000000,4500.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865384), 'uid': 'CcqB9mjglLGELhiQ6', 'id.orig_h': 'fe80::219:e3ff:fee7:5d23', 'id.orig_p': 5353, 'id.resp_h': 'ff02::fb', 'id.resp_p': 5353, 'proto': 'udp', 'trans_id': 0, 'rtt': datetime.timedelta(microseconds=1), 'query': '_smb._tcp.local', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 12, 'qtype_name': 'PTR', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': True, 'TC': False, 'RD': False, 'RA': False, 'Z': 0, 'answers': 'TXT 15 model=Xserve1\\x2c1,domex.nps.edu._smb._tcp.local', 'TTLs': '4500.000000,4500.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865787), 'uid': 'CsQkcr26zqaG3FQGDl', 'id.orig_h': '192.168.1.103', 'id.orig_p': 1207, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 2651, 'rtt': datetime.timedelta(0), 'query': 'sn21.mailshell.net', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '87.106.9.29,87.106.12.47,87.106.12.77,87.106.13.61,87.106.13.62,212.227.96.110,212.227.97.133,87.106.1.89', 'TTLs': '10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 53, 427599), 'uid': 'CEsd6r19IENh8myBP1', 'id.orig_h': '192.168.1.103', 'id.orig_p': 65326, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 36137, 'rtt': datetime.timedelta(0), 'query': 'go.microsoft.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'www.go.microsoft.akadns.net,207.46.16.233', 'TTLs': '3600.000000,600.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 53, 427605), 'uid': 'Cz3ZjzRJ6dwTzfFc', 'id.orig_h': '192.168.1.103', 'id.orig_p': 51398, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 10227, 'rtt': datetime.timedelta(microseconds=1), 'query': 'www.msn.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'us.co1.cb3.glbdns.microsoft.com,65.55.17.27', 'TTLs': '900.000000,300.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 53, 427627), 'uid': 'CAZyJc2Wowy0Ghtrx5', 'id.orig_h': '192.168.1.103', 'id.orig_p': 59845, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 50735, 'rtt': datetime.timedelta(microseconds=1), 'query': 'msnportal.112.2o7.net', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '66.235.138.19,66.235.138.44,66.235.139.54,66.235.139.118,66.235.139.121,66.235.139.152,66.235.138.2,66.235.138.18', 'TTLs': '900.000000,900.000000,900.000000,900.000000,900.000000,900.000000,900.000000,900.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 53, 427631), 'uid': 'CgbJzd1psTNeRyrk3j', 'id.orig_h': '192.168.1.103', 'id.orig_p': 64703, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 20810, 'rtt': datetime.timedelta(microseconds=1), 'query': 'exp.www.msn.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'ro-msn.exp.glbdns.microsoft.com,65.55.18.18', 'TTLs': '900.000000,300.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 53, 427632), 'uid': 'CbtSJt2HTmcE6urEZd', 'id.orig_h': '192.168.1.103', 'id.orig_p': 54645, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 21350, 'rtt': datetime.timedelta(microseconds=809), 'query': 'www.bing.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'search.ms.com.edgesuite.net,a134.g.akamai.net,198.189.255.73,198.189.255.82', 'TTLs': '3600.000000,21600.000000,20.000000,20.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 53, 428444), 'uid': 'CpRzhz30FXw2bhwo6d', 'id.orig_h': '192.168.1.103', 'id.orig_p': 64704, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 35335, 'rtt': datetime.timedelta(0), 'query': 'c.msn.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'c.msn.com.nsatc.net,65.55.239.188', 'TTLs': '900.000000,300.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 53, 428446), 'uid': 'Cnt4KHaZF0LocjFD8', 'id.orig_h': '192.168.1.103', 'id.orig_p': 52088, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 11670, 'rtt': datetime.timedelta(0), 'query': 'rad.msn.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'rad.msn.com.nsatc.net,65.55.15.124,65.55.15.243', 'TTLs': '900.000000,300.000000,300.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 53, 428449), 'uid': 'CdWM3VbsMjxZdRbv', 'id.orig_h': '192.168.1.103', 'id.orig_p': 64705, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 37753, 'rtt': datetime.timedelta(microseconds=1), 'query': 'col.stb.s-msn.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'colstb.co1.cb3.glbdns.microsoft.com,msn.vo.msecnd.net,65.54.95.198,65.54.95.204', 'TTLs': '3600.000000,300.000000,300.000000,300.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 53, 428455), 'uid': 'CP7H1wsD0kIKuAYL8', 'id.orig_h': '192.168.1.103', 'id.orig_p': 60864, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 25581, 'rtt': datetime.timedelta(0), 'query': 'a.rad.msn.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'rad.msn.com,rad.msn.com.nsatc.net,65.55.15.243,65.55.15.124', 'TTLs': '900.000000,898.000000,298.000000,298.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 53, 428482), 'uid': 'CObxl12l7F5kNcInfg', 'id.orig_h': '192.168.1.103', 'id.orig_p': 64706, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 47917, 'rtt': datetime.timedelta(microseconds=1), 'query': 'b.rad.msn.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'rad.msn.com,rad.msn.com.nsatc.net,65.55.15.124,65.55.15.243', 'TTLs': '900.000000,894.000000,294.000000,294.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 53, 428714), 'uid': 'CGX0aM2iL4rxvb7Wul', 'id.orig_h': '192.168.1.103', 'id.orig_p': 50799, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 28035, 'rtt': datetime.timedelta(microseconds=1), 'query': 'ad.doubleclick.net', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'dart-ad.l.doubleclick.net,74.125.19.149,74.125.19.148', 'TTLs': '300.000000,300.000000,300.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 53, 428717), 'uid': 'Csw88g3uX6Rq36Ewul', 'id.orig_h': '192.168.1.103', 'id.orig_p': 52397, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 33769, 'rtt': datetime.timedelta(microseconds=3), 'query': 'b.ads2.msn.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'ads2.msn.com,ads2.msn.com.c.footprint.net,209.84.4.126,4.23.63.126,204.160.122.126', 'TTLs': '900.000000,900.000000,230.000000,230.000000,230.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 54, 692772), 'uid': 'CfPYLu4vBGuEjA1vz3', 'id.orig_h': '192.168.1.103', 'id.orig_p': 55050, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 15701, 'rtt': datetime.timedelta(0), 'query': 'www.uspto.gov', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '151.207.243.129,151.207.247.130', 'TTLs': '7200.000000,7200.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 54, 884725), 'uid': 'Cch5N91VqjEFWptNbi', 'id.orig_h': '192.168.1.103', 'id.orig_p': 64707, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 33750, 'rtt': datetime.timedelta(0), 'query': 'mail.m57.biz', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '208.97.132.223', 'TTLs': '13539.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 54, 885144), 'uid': 'CE1GanDHGnptkpcya', 'id.orig_h': '192.168.1.103', 'id.orig_p': 1394, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 30552, 'rtt': datetime.timedelta(0), 'query': 'sn21.mailshell.net', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '87.106.1.47,87.106.9.29,87.106.12.77,87.106.13.61,87.106.13.62,87.106.66.233,212.227.96.110,212.227.97.133', 'TTLs': '10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000,10.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 54, 940397), 'uid': 'CfbZMi2tAYvjlKcxGe', 'id.orig_h': '192.168.1.105', 'id.orig_p': 49218, 'id.resp_h': '192.168.1.1', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 63955, 'rtt': datetime.timedelta(0), 'query': 'time-a.timefreq.bldrdoc.gov', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '132.163.4.103,132.163.4.101,132.163.4.102', 'TTLs': '36625.000000,36625.000000,36625.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863238), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 32995, 'rtt': datetime.timedelta(0), 'query': 'DOMEX', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863239), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 32998, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863239), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 32998, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863240), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 32998, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863831), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33008, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863832), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33008, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863832), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33008, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864772), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33045, 'rtt': datetime.timedelta(0), 'query': 'WPAD.M57.BIZ.', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864772), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33045, 'rtt': datetime.timedelta(0), 'query': 'WPAD.M57.BIZ.', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864773), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33045, 'rtt': datetime.timedelta(0), 'query': 'WPAD.M57.BIZ.', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864776), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33046, 'rtt': datetime.timedelta(0), 'query': 'WPAD.M57.BIZ.', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864776), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33046, 'rtt': datetime.timedelta(0), 'query': 'WPAD.M57.BIZ.', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864776), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33046, 'rtt': datetime.timedelta(0), 'query': 'WPAD.M57.BIZ.', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865387), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33047, 'rtt': datetime.timedelta(0), 'query': 'DOMEX', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864344), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33011, 'rtt': datetime.timedelta(0), 'query': 'DOMEX', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863829), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33002, 'rtt': datetime.timedelta(0), 'query': 'DOMEX', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863830), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33005, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863830), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33005, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863831), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33005, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864346), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33017, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864346), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33017, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864346), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33017, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865580), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33059, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865581), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33059, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865581), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33059, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864345), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33014, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864345), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33014, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864345), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33014, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864568), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33035, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864568), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33035, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864568), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33035, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864762), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33038, 'rtt': datetime.timedelta(0), 'query': 'DOMEX', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865773), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33068, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865773), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33068, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865773), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33068, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864566), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33032, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864567), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33032, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864567), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33032, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865581), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33062, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865581), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33062, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865582), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33062, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864763), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33041, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864764), 'uid': 'CtfL4w3ITZJMibpXH5', 'id.orig_h': '192.168.1.104', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33041, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# ...
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864760), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33051, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864760), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33051, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 54, 988196), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33382, 'rtt': datetime.timedelta(0), 'query': 'DOMEX', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863850), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33020, 'rtt': datetime.timedelta(0), 'query': 'DOMEX', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865380), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33054, 'rtt': datetime.timedelta(0), 'query': 'DOMEX', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864563), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33044, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864563), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33044, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864564), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33044, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863851), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33023, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863851), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33023, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863852), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33023, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865574), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33066, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865574), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33066, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865575), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33066, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863852), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33026, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863853), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33026, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 863853), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33026, 'rtt': datetime.timedelta(0), 'query': 'WORKGROUP', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865573), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33063, 'rtt': datetime.timedelta(0), 'query': 'DOMEX', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 865767), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33072, 'rtt': datetime.timedelta(0), 'query': 'DOMEX', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 30, 52, 864365), 'uid': 'CaZDbT2DQshVFLVE1j', 'id.orig_h': '192.168.1.102', 'id.orig_p': 137, 'id.resp_h': '192.168.1.255', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 33029, 'rtt': datetime.timedelta(0), 'query': 'DOMEX', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 32, 'qtype_name': 'NB', 'rcode': 0, 'rcode_name': '-', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 1, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 31, 33, 221963), 'uid': 'CLayzR29gVl0GtsSAh', 'id.orig_h': '10.220.170.105', 'id.orig_p': 60503, 'id.resp_h': '8.8.4.4', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 40720, 'rtt': datetime.timedelta(microseconds=24740), 'query': 'api-0.core.keybaseapi.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '52.86.228.211,52.6.171.68', 'TTLs': '56.000000,56.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 31, 33, 222293), 'uid': 'CXfaSm4TlnFIc3oT68', 'id.orig_h': '10.220.170.105', 'id.orig_p': 61305, 'id.resp_h': '8.8.4.4', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 15405, 'rtt': datetime.timedelta(0), 'query': 'api-0.core.keybaseapi.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 28, 'qtype_name': 'AAAA', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 0, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 31, 41, 693647), 'uid': 'CcmKG921OfgPoyapp1', 'id.orig_h': '10.220.170.105', 'id.orig_p': 49848, 'id.resp_h': '8.8.4.4', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 14851, 'rtt': datetime.timedelta(microseconds=23949), 'query': 'api.keybase.io', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '52.4.215.1,35.153.89.209', 'TTLs': '30.000000,30.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 31, 41, 694585), 'uid': 'CV9aVg22e26Hv7trEe', 'id.orig_h': '10.220.170.105', 'id.orig_p': 63192, 'id.resp_h': '8.8.4.4', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 49080, 'rtt': datetime.timedelta(0), 'query': 'api.keybase.io', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 28, 'qtype_name': 'AAAA', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 0, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 31, 55, 182059), 'uid': 'CG4z6s21EKMyFcokii', 'id.orig_h': '10.220.170.105', 'id.orig_p': 65042, 'id.resp_h': '8.8.4.4', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 46159, 'rtt': datetime.timedelta(0), 'query': 'ghs-svc-https-c46.ghs-ssl.googlehosted.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 28, 'qtype_name': 'AAAA', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': False, 'Z': 0, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 31, 55, 155514), 'uid': 'C7e8sW1eB5rQUWmUh4', 'id.orig_h': '10.1.10.73', 'id.orig_p': 137, 'id.resp_h': '10.1.10.162', 'id.resp_p': 137, 'proto': 'udp', 'trans_id': 59451, 'rtt': datetime.timedelta(0), 'query': '-', 'qclass': 0, 'qclass_name': '-', 'qtype': 0, 'qtype_name': '-', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': False, 'RA': False, 'Z': 0, 'answers': '-', 'TTLs': '-', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 33, 3, 220618), 'uid': 'CusdHv19X8Hbh2qwoe', 'id.orig_h': '10.220.170.105', 'id.orig_p': 53097, 'id.resp_h': '8.8.4.4', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 24894, 'rtt': datetime.timedelta(microseconds=26145), 'query': 'outlook.office365.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 28, 'qtype_name': 'AAAA', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'outlook.ms-acdc.office.com,sjc-efz.ms-acdc.office.com,2603:1036:307:2840::2,2603:1036:307:2874::2,2603:1036:307:4040::2,2603:1036:a03::2', 'TTLs': '142.000000,40.000000,47.000000,47.000000,47.000000,47.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 33, 3, 220956), 'uid': 'C9DnOMHbGhf6H2cad', 'id.orig_h': '10.220.170.105', 'id.orig_p': 51503, 'id.resp_h': '8.8.4.4', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 40750, 'rtt': datetime.timedelta(microseconds=26461), 'query': 'outlook.office365.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': 'outlook.ms-acdc.office.com,sjc-efz.ms-acdc.office.com,52.96.31.2,52.96.70.130,52.96.3.178,52.96.59.162', 'TTLs': '144.000000,42.000000,42.000000,42.000000,42.000000,42.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 33, 3, 247436), 'uid': 'C9DnOMHbGhf6H2cad', 'id.orig_h': '10.220.170.105', 'id.orig_p': 51503, 'id.resp_h': '8.8.4.4', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 40750, 'rtt': datetime.timedelta(microseconds=23721), 'query': 'sjc-efz.ms-acdc.office.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '40.97.222.194,52.96.3.130,40.97.222.34,52.96.31.2', 'TTLs': '29.000000,29.000000,29.000000,29.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 33, 7, 723775), 'uid': 'Cr8rnb1cbl9CEOi6Of', 'id.orig_h': '10.220.170.105', 'id.orig_p': 50817, 'id.resp_h': '8.8.4.4', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 57354, 'rtt': datetime.timedelta(microseconds=24758), 'query': 'safebrowsing.googleapis.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 1, 'qtype_name': 'A', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '172.217.5.202', 'TTLs': '151.000000', 'rejected': False}
# {'ts': datetime.datetime(2019, 9, 10, 6, 33, 7, 722858), 'uid': 'CzaJQa1q7C0uAGQm12', 'id.orig_h': '10.220.170.105', 'id.orig_p': 58723, 'id.resp_h': '8.8.4.4', 'id.resp_p': 53, 'proto': 'udp', 'trans_id': 19831, 'rtt': datetime.timedelta(microseconds=50635), 'query': 'safebrowsing.googleapis.com', 'qclass': 1, 'qclass_name': 'C_INTERNET', 'qtype': 28, 'qtype_name': 'AAAA', 'rcode': 0, 'rcode_name': 'NOERROR', 'AA': False, 'TC': False, 'RD': True, 'RA': True, 'Z': 0, 'answers': '2607:f8b0:4007:80d::200a', 'TTLs': '299.000000', 'rejected': False}
